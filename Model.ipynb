# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense 
from sklearn.metrics import confusion_matrix, accuracy_score
from tensorflow.keras.models import load_model
import warnings 
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('Churn_Modelling.csv')

# %%
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# 4         79084.10       0

# %%
df.shape
# Out:
# (10000, 14)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           10000 non-null  object
#  6   Age              10000 non-null  int64
#  7   Tenure           10000 non-null  int64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(2), int64(9), object(3)
# memory usage: 1.1+ MB

# %%
df.isnull().sum()
# Out:
# RowNumber          0
# CustomerId         0
# Surname            0
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %%
# <<--- Independent and Dependent Variables --->>

X = df.iloc[:, 3:-1]
Y = df['Exited']

# %%
# <<-- Encode Categorical Data -->>

X = pd.get_dummies(data=X, drop_first=True)

# %%
# <<-- Train Test Split -->>

x_train, x_test, y_train, y_test = train_test_split(X, Y, train_size=0.8, test_size=0.2, random_state=0)

# %%
# <<-- Scale Data -->>

ss = StandardScaler()
x_train = ss.fit_transform(x_train)
x_test = ss.transform(x_test)

# %%
# <<-- Make Neural Network -->>

ann = Sequential()

layer1 = Dense(units=6, activation='relu')  # First Hidden Layer
layer2 = Dense(units=6, activation='relu')  # Second Hidden Layer
output_layer = Dense(units=1, activation='sigmoid')  # Output Layer

# Add all layers to ANN model

ann.add(layer1)
ann.add(layer2)
ann.add(output_layer)

# %%
# <<-- Train Neural Network --->>

ann.compile(optimizer='adam', loss='binary_crossentropy', metrics='accuracy')  # Compile ANN
ann.fit(x_train, y_train, batch_size=32, epochs=100) # Train ANN
# Out:
# Epoch 1/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.5752 - accuracy: 0.7595
# Epoch 2/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.4646 - accuracy: 0.7962
# Epoch 3/100
# 250/250 [==============================] - 1s 2ms/step - loss: 0.4416 - accuracy: 0.7980
# Epoch 4/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.4323 - accuracy: 0.8092
# Epoch 5/100
# 250/250 [==============================] - 1s 2ms/step - loss: 0.4267 - accuracy: 0.8174
# Epoch 6/100
# 250/250 [==============================] - 1s 2ms/step - loss: 0.4228 - accuracy: 0.8186
# Epoch 7/100
# 250/250 [==============================] - 1s 2ms/step - loss: 0.4193 - accuracy: 0.8209
# Epoch 8/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.4161 - accuracy: 0.8238
# Epoch 9/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.4133 - accuracy: 0.8241
# Epoch 10/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.4113 - accuracy: 0.8224
# Epoch 11/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.4091 - accuracy: 0.8259
# Epoch 12/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.4069 - accuracy: 0.8274
# Epoch 13/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.4053 - accuracy: 0.8275
# Epoch 14/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.4034 - accuracy: 0.8284
# Epoch 15/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.4016 - accuracy: 0.8288
# Epoch 16/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.3999 - accuracy: 0.8305
# Epoch 17/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.3977 - accuracy: 0.8299
# Epoch 18/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.3947 - accuracy: 0.8305
# Epoch 19/100
# 250/250 [==============================] - 1s 2ms/step - loss: 0.3909 - accuracy: 0.8295
# Epoch 20/100
# 250/250 [==============================] - 1s 2ms/step - loss: 0.3861 - accuracy: 0.8345
# Epoch 21/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3806 - accuracy: 0.8403
# Epoch 22/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3751 - accuracy: 0.8432
# Epoch 23/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.3683 - accuracy: 0.8455
# Epoch 24/100
# 250/250 [==============================] - 1s 2ms/step - loss: 0.3627 - accuracy: 0.8487
# Epoch 25/100
# 250/250 [==============================] - 1s 2ms/step - loss: 0.3570 - accuracy: 0.8510
# Epoch 26/100
# 250/250 [==============================] - 1s 2ms/step - loss: 0.3520 - accuracy: 0.8551
# Epoch 27/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.3485 - accuracy: 0.8574
# Epoch 28/100
# 250/250 [==============================] - 1s 2ms/step - loss: 0.3450 - accuracy: 0.8594
# Epoch 29/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.3431 - accuracy: 0.8624
# Epoch 30/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.3414 - accuracy: 0.8608
# Epoch 31/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3402 - accuracy: 0.8611
# Epoch 32/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.3393 - accuracy: 0.8612
# Epoch 33/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.3385 - accuracy: 0.8631
# Epoch 34/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.3376 - accuracy: 0.8614
# Epoch 35/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.3375 - accuracy: 0.8614
# Epoch 36/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.3371 - accuracy: 0.8634
# Epoch 37/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.3366 - accuracy: 0.8625
# Epoch 38/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.3363 - accuracy: 0.8627
# Epoch 39/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.3361 - accuracy: 0.8634
# Epoch 40/100
# 250/250 [==============================] - 1s 2ms/step - loss: 0.3361 - accuracy: 0.8633
# Epoch 41/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.3356 - accuracy: 0.8636
# Epoch 42/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.3354 - accuracy: 0.8627
# Epoch 43/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.3352 - accuracy: 0.8639
# Epoch 44/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.3351 - accuracy: 0.8626
# Epoch 45/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.3346 - accuracy: 0.8641
# Epoch 46/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.3347 - accuracy: 0.8629
# Epoch 47/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.3344 - accuracy: 0.8634
# Epoch 48/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.3343 - accuracy: 0.8622
# Epoch 49/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.3340 - accuracy: 0.8631
# Epoch 50/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.3341 - accuracy: 0.8625
# Epoch 51/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.3338 - accuracy: 0.8635
# Epoch 52/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.3339 - accuracy: 0.8639
# Epoch 53/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.3333 - accuracy: 0.8635
# Epoch 54/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.3336 - accuracy: 0.8645
# Epoch 55/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.3330 - accuracy: 0.8650
# Epoch 56/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.3333 - accuracy: 0.8630
# Epoch 57/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.3329 - accuracy: 0.8646
# Epoch 58/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.3328 - accuracy: 0.8641
# Epoch 59/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3328 - accuracy: 0.8643
# Epoch 60/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3326 - accuracy: 0.8651
# Epoch 61/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3323 - accuracy: 0.8645
# Epoch 62/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3323 - accuracy: 0.8651
# Epoch 63/100
# 250/250 [==============================] - ETA: 0s - loss: 0.3352 - accuracy: 0.86 - 0s 1ms/step - loss: 0.3320 - accuracy: 0.8643
# Epoch 64/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.3317 - accuracy: 0.8639
# Epoch 65/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3319 - accuracy: 0.8645
# Epoch 66/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3316 - accuracy: 0.8636
# Epoch 67/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3315 - accuracy: 0.8652
# Epoch 68/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3315 - accuracy: 0.8648
# Epoch 69/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.3315 - accuracy: 0.8644
# Epoch 70/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.3314 - accuracy: 0.8648
# Epoch 71/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.3315 - accuracy: 0.8651
# Epoch 72/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.3311 - accuracy: 0.8646
# Epoch 73/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3312 - accuracy: 0.8644
# Epoch 74/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.3309 - accuracy: 0.8637
# Epoch 75/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.3310 - accuracy: 0.8650
# Epoch 76/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.3310 - accuracy: 0.8645
# Epoch 77/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.3309 - accuracy: 0.8651
# Epoch 78/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3308 - accuracy: 0.8652
# Epoch 79/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3311 - accuracy: 0.8648
# Epoch 80/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3304 - accuracy: 0.8656
# Epoch 81/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3304 - accuracy: 0.8643
# Epoch 82/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3304 - accuracy: 0.8646
# Epoch 83/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.3306 - accuracy: 0.8648
# Epoch 84/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.3305 - accuracy: 0.8650
# Epoch 85/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.3302 - accuracy: 0.8659
# Epoch 86/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3304 - accuracy: 0.8654
# Epoch 87/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3305 - accuracy: 0.8654
# Epoch 88/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.3302 - accuracy: 0.8650
# Epoch 89/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.3303 - accuracy: 0.8660
# Epoch 90/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.3300 - accuracy: 0.8643
# Epoch 91/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.3302 - accuracy: 0.8650
# Epoch 92/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.3300 - accuracy: 0.8652
# Epoch 93/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3297 - accuracy: 0.8645
# Epoch 94/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3304 - accuracy: 0.8651
# Epoch 95/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3299 - accuracy: 0.8654
# Epoch 96/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3300 - accuracy: 0.8662
# Epoch 97/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3299 - accuracy: 0.8646
# Epoch 98/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3294 - accuracy: 0.8660
# Epoch 99/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3295 - accuracy: 0.8654
# Epoch 100/100
# 250/250 [==============================] - 0s 2ms/step - loss: 0.3297 - accuracy: 0.8643

# %%
# Preidict values

y_pred = ann.predict(x_test)

# %%
thresh = 0.5  # Threshold

y_pred = [1 if i[0] > thresh else 0 for i in y_pred]

# %%
# Confusion Matrix and Accuracy Score

cm = confusion_matrix(y_test, y_pred)
print(cm)
accuracy_score(y_test, y_pred)
# Out:
# [[1514   81]
#  [ 201  204]]
# 0.859

# %%
# <<-- Save Model in HDF5 file format -->>

ann.save("network.h5")

# %%
# <<-- Load the saved model -->>

loaded_model = load_model("network.h5") # Load the model
loss, accuracy = loaded_model.evaluate(x_test, y_test) # Test the accuracy on test data
# Out:
# 63/63 [==============================] - 0s 1ms/step - loss: 0.3300 - accuracy: 0.8590
